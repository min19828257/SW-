# %% [markdown]
# # Segmentation with OPENCV

# %%
import cv2
import matplotlib.pyplot as plt

def main():
    img = cv2.imread('./hani.jpg')
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    
    plt.imshow(img)
    plt.show()
    
main()

# %% [markdown]
# # 연습용

# %%
import torch
import torch.nn.functional as F
from torch import nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
from torchvision.transforms import Compose, RandomCrop, ToTensor, Resize
from os import listdir
from os.path import join
from PIL import Image
import cv2

NUM_EPOCHS = 5
loadmodel = 'param/netD_epoch_5.pth'
GPUUSE = True

def is_image_file(filename):
    return any(filename.endswith(extension) for extension in ['bmp', '.png', '.jpg', '.jpeg', '.PNG', '.JPG', '.JPEG'])

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layer1 = torch.nn.Sequential(
            torch.nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer2 = torch.nn.Sequential(
            torch.nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2))
        self.layer3 = torch.nn.Sequential(
            torch.nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            torch.nn.ReLU(),
            torch.nn.MaxPool2d(kernel_size=2, stride=2))
        
        # Final FC 7x7x64 inputs -> 10 outputs
        self.fc = torch.nn.Linear(7 * 7* 128, 625, bias=True)
        torch.nn.ReLU()
        self.fc2 = torch.nn.Linear(625, 2, bias=True)
        torch.nn.init.xavier_uniform_(self.fc.weight)


    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out = out.view(out.size(0), -1)   # Flatten them for FC
        out = self.fc(out)
        out = self.fc2(out)
        return out

class DatasetFromfolder(Dataset):
    def __init__(self, facedataset_dir, nonfacedataset_dir):
        super(DatasetFromfolder, self).__init__()
        self.face_image_filenames = [join(facedataset_dir, x)for x in listdir(facedataset_dir) if is_image_file(x)]
        self.nonface_image_filenames = [join(nonfacedataset_dir,x)for x in listdir(nonfacedataset_dir) if is_image_file(x)]
        
        #print("self.face_image : ",self.face_image_filenames)
        #print("self.nonface_image : ",self.nonface_image_filenames)
        
        self.face_transform = Compose([ToTensor()])
        self.nonface_transform = Compose([ToTensor()])

    def __getitem__(self, index):
        
        
        ID = self.face_image_filenames[index]
        print("ID : ", ID)
        X = torch.load(ID)
        y = self.labels[ID]
        #####
        #
        #
        #####

        #return resultimage, label

    def __len__(self):
        return ######

def train():

    train_set = DatasetFromfolder("./data/0","./data/1")
    print(train_set[0])
    
    batch_size = 64
    #val_set = #
    train_loader = torch.utils.data.DataLoader(dataset=train_set,
                                              batch_size=batch_size,
                                              shuffle=True,
                                              drop_last=True)
    #val_loader = #


    # 네트워크 불러오기
    print('# discriminator parameters:', sum(param.numel() for param in netD.parameters()))

    # parameter가 있다면 불러오는 부분
    
    out =net(asdfas)
    # loss 와 optimizer 정의

    # 실제 train이 돌아가는 for문:
        #dataloader에서 input을 받고 학습시키는 부분
        #필요하다면 validation set으로 loss 확인
        #매 epoch 마다 parameter를 저장하기


def test():
    print("1")

    # 네트워크 불러오기

    # parameter 받아오기

    # test할 data 받아오기 (인터넷에서 아무거나 받아와서 확인해봐도 됨!)

    # 네트워크 통과시켜서 결과 display

train()
#test()
# Out:
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-36-ef084c378fe4> in <module>
#     118     # 네트워크 통과시켜서 결과 display
#     119
# --> 120 train()
#     121 #test()
#
# <ipython-input-36-ef084c378fe4> in train()
#      82
#      83     train_set = DatasetFromfolder("./data/0","./data/1")
# ---> 84     print(train_set[0])
#      85
#      86     batch_size = 64
#
# <ipython-input-36-ef084c378fe4> in __getitem__(self, index)
#      67         ID = self.face_image_filenames[index]
#      68         print("ID : ", ID)
# ---> 69         X = torch.load(ID)
#      70         y = self.labels[ID]
#      71         #####
#
# D:\anaconda\envs\pytorch\lib\site-packages\torch\serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     385         f = f.open('rb')
#     386     try:
# --> 387         return _load(f, map_location, pickle_module, **pickle_load_args)
#     388     finally:
#     389         if new_fd:
#
# D:\anaconda\envs\pytorch\lib\site-packages\torch\serialization.py in _load(f, map_location, pickle_module, **pickle_load_args)
#     562             f.seek(0)
#     563
# --> 564     magic_number = pickle_module.load(f, **pickle_load_args)
#     565     if magic_number != MAGIC_NUMBER:
#     566         raise RuntimeError("Invalid magic number; corrupt file?")
#
# UnpicklingError: invalid load key, '\xff'.

# %%
    img = cv2.imread('./hani.jpg')
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    
    plt.imshow(img)
    plt.show()

# %%
import torch
import torch.nn.functional as F
from torch import nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
from torchvision.transforms import Compose, RandomCrop, ToTensor, Resize

from os import listdir
from os.path import join
from PIL import Image

import cv2

NUM_EPOCHS = 5
#이전에 시행했던 로드파일
loadmodel = None
GPUUSE = None

def is_image_file(filename):
    return any(filename.endswith(extension) for extension in ['bmp', '.png', '.jpg', '.jpeg', '.PNG', '.JPG', '.JPEG'])

class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.net = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=3, padding=1),
            nn.LeakyReLU(0.2),

            nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),

            nn.Conv2d(128, 128, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.Conv2d(256, 256, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),

            nn.Conv2d(512, 512, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),

            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(512, 1024, kernel_size=1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(1024, 1, kernel_size=1)
        )

    def forward(self, x):
        return F.sigmoid(self.net(x))

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.conv3 = nn.Conv2d(16, 32, 3)
        self.conv4 = nn.Conv2d(32, 64, 3)

        self.fc1 = nn.Linear(64 * 6 * 6, 256)
        self.fc2 = nn.Linear(256, 64)
        self.fc3 = nn.Linear(64, 1)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = self.pool(F.relu(self.conv4(x)))
        x = x.view(-1, 64 * 6 * 6)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return torch.sigmoid(x)

# save load 코드 예시
#torch.save(netD.state_dict(), 'param/netD_epoch_%d.pth' % (epoch))

#net.load_state_dict(torch.load(loadmodel))

class DatasetFromfolder(Dataset):
    def __init__(self, facedataset_dir, nonfacedataset_dir):
        super(DatasetFromfolder, self).__init__()
        self.face_image_filenames = [join(facedataset_dir, x) for x in listdir(facedataset_dir) if is_image_file(x)]
        self.nonface_image_filenames = [join(nonfacedataset_dir, x) for x in listdir(nonfacedataset_dir) if is_image_file(x)]

        self.face_transform = Compose([ToTensor()])
        self.nonface_transform = Compose([RandomCrop(144),ToTensor()])


    def __getitem__(self, index):
        resultimage = 0
        label = 0
        if index < len(self.face_image_filenames):
            resultimage = self.face_transform(Image.open(self.face_image_filenames[index]).convert('L'))
            label = torch.ones(1)
        else:
            resultimage = self.nonface_transform(Image.open(self.nonface_image_filenames[index - len(self.face_image_filenames)]))
            label = torch.zeros(1)

        return resultimage, label

    def __len__(self):
        return len(self.face_image_filenames) + len(self.nonface_image_filenames)



def train():
    train_set = DatasetFromfolder('./data/1', './data/0')
    val_set = DatasetFromfolder('./data/1', './data/0')
    train_loader = DataLoader(dataset=train_set, num_workers=0, batch_size=64, shuffle=True)
    val_loader = DataLoader(dataset=val_set, num_workers=0, batch_size=1, shuffle=True)

    GPUUSE = None

    # netD = Discriminator()
    netD = Net()
    print('# discriminator parameters:', sum(param.numel() for param in netD.parameters()))

    criterion = nn.MSELoss()
    if loadmodel is not None:
        print("=> loading checkpoint '{}'".format(loadmodel))
        netD.load_state_dict(torch.load(loadmodel))
    if GPUUSE == None:
        netD.cpu()
    else:
        if torch.cuda.is_available():
            netD.cuda()

    optimizerD = optim.Adam(netD.parameters())

    for epoch in range(1, NUM_EPOCHS + 1):

        netD.train()
        batch_idx = 0
        for sample, label in train_loader:
            batch_size = sample.size(0)

            if GPUUSE == None:
                face = sample.cpu()
                label = label.cpu()
            else:
                if torch.cuda.is_available():
                    face = sample.cuda()
                    label = label.cuda()


            netD.zero_grad()
            out = netD(face)

            d_loss = criterion(out.squeeze(), label.squeeze())
            d_loss.backward(retain_graph=True)
            optimizerD.step()


            with torch.no_grad():
                for val_face, val_label in val_loader:
                    # if torch.cuda.is_available():
                    #     val_face = val_face.cuda()
                    #     val_label = val_label.cuda()

                    val_out = netD(val_face)

                    Val_loss = criterion(val_out, val_label)

                    print('Epoch [{}/{}], BatchStep[{}/{}], Loss: {}'.format(epoch, NUM_EPOCHS, batch_idx, batch_size, Val_loss))

            batch_idx += 1

        torch.save(netD.state_dict(), 'param/netD_epoch_%d.pth' % (epoch))


def test():
    print("test session")

    # netD = Discriminator()
    net = Net()
    print('# discriminator parameters:', sum(param.numel() for param in net.parameters()))

    if GPUUSE == None:
        net.cpu()
    else:
        if torch.cuda.is_available():
            net.cuda()

    if loadmodel is not None:
        print("=> loading checkpoint '{}'".format(loadmodel))
        net.load_state_dict(torch.load(loadmodel))


    net.eval()

    img_name = "hani.jpg"
    img = Image.open(img_name).convert('L')
    # img = Image.open("data/binary_cls/IU2.png").convert('L')
    trans = Compose([Resize([144,144]),ToTensor()])

    img = trans(img).unsqueeze(1)
    if GPUUSE != None:
        img = img.cuda()

    ###cv2 로도 되나
    # im = cv2.imread("data/binary_cls/IU2.png", 0).astype('float32')
    # im = cv2.resize(im, (144, 144)) / 256
    # im = torch.from_numpy(im)
    # im = im.unsqueeze(0).unsqueeze(0).cuda()
    #################

    output = net(img)

    im = cv2.imread(img_name)
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(im, "%0.4f"%float(output), (10, 100), font, 1, (255, 255, 255), 2, cv2.LINE_AA)
    cv2.imshow("im",im)
    cv2.waitKey()

    print(output)

    # img = Image.open("data/binary_cls/val_nonface/5.jpg")
    # trans = Compose([RandomCrop(144),ToTensor()])
    # img = trans(img).unsqueeze(1)
    # if GPUUSE != None:
    #     img = img.cuda()
    #
    # output = net(img)
    # print(output)

if __name__ == "__main__":
    #train()
     test()
# Out:
# # discriminator parameters: 632301
# Epoch [1/5], BatchStep[0/64], Loss: 0.22736111283302307
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731427252292633
# Epoch [1/5], BatchStep[0/64], Loss: 0.22730711102485657
# Epoch [1/5], BatchStep[0/64], Loss: 0.22759920358657837
# Epoch [1/5], BatchStep[0/64], Loss: 0.27296754717826843
# Epoch [1/5], BatchStep[0/64], Loss: 0.22759351134300232
# Epoch [1/5], BatchStep[0/64], Loss: 0.27314096689224243
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730986773967743
# Epoch [1/5], BatchStep[0/64], Loss: 0.2274552285671234
# Epoch [1/5], BatchStep[0/64], Loss: 0.273143470287323
# Epoch [1/5], BatchStep[0/64], Loss: 0.22775264084339142
# Epoch [1/5], BatchStep[0/64], Loss: 0.22662799060344696
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284073829650879
# Epoch [1/5], BatchStep[0/64], Loss: 0.27300816774368286
# Epoch [1/5], BatchStep[0/64], Loss: 0.22760090231895447
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730900049209595
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276606261730194
# Epoch [1/5], BatchStep[0/64], Loss: 0.22761887311935425
# Epoch [1/5], BatchStep[0/64], Loss: 0.27304553985595703
# Epoch [1/5], BatchStep[0/64], Loss: 0.226749449968338
# Epoch [1/5], BatchStep[0/64], Loss: 0.22731831669807434
# Epoch [1/5], BatchStep[0/64], Loss: 0.22675804793834686
# Epoch [1/5], BatchStep[0/64], Loss: 0.27315977215766907
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730976641178131
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276630997657776
# Epoch [1/5], BatchStep[0/64], Loss: 0.22750627994537354
# Epoch [1/5], BatchStep[0/64], Loss: 0.22743484377861023
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275739163160324
# Epoch [1/5], BatchStep[0/64], Loss: 0.22807514667510986
# Epoch [1/5], BatchStep[0/64], Loss: 0.22757667303085327
# Epoch [1/5], BatchStep[0/64], Loss: 0.22804827988147736
# Epoch [1/5], BatchStep[0/64], Loss: 0.2281823307275772
# Epoch [1/5], BatchStep[0/64], Loss: 0.22677655518054962
# Epoch [1/5], BatchStep[0/64], Loss: 0.22817794978618622
# Epoch [1/5], BatchStep[0/64], Loss: 0.226982980966568
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730783522129059
# Epoch [1/5], BatchStep[0/64], Loss: 0.22775736451148987
# Epoch [1/5], BatchStep[0/64], Loss: 0.2273469865322113
# Epoch [1/5], BatchStep[0/64], Loss: 0.273090124130249
# Epoch [1/5], BatchStep[0/64], Loss: 0.27297234535217285
# Epoch [1/5], BatchStep[0/64], Loss: 0.22731944918632507
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284073531627655
# Epoch [1/5], BatchStep[0/64], Loss: 0.27303189039230347
# Epoch [1/5], BatchStep[0/64], Loss: 0.273045152425766
# Epoch [1/5], BatchStep[0/64], Loss: 0.22785383462905884
# Epoch [1/5], BatchStep[0/64], Loss: 0.22761836647987366
# Epoch [1/5], BatchStep[0/64], Loss: 0.22840458154678345
# Epoch [1/5], BatchStep[0/64], Loss: 0.27306845784187317
# Epoch [1/5], BatchStep[0/64], Loss: 0.2277083843946457
# Epoch [1/5], BatchStep[0/64], Loss: 0.22759050130844116
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282649427652359
# Epoch [1/5], BatchStep[0/64], Loss: 0.22833551466464996
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730265259742737
# Epoch [1/5], BatchStep[0/64], Loss: 0.22842788696289062
# Epoch [1/5], BatchStep[0/64], Loss: 0.22739988565444946
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729966938495636
# Epoch [1/5], BatchStep[0/64], Loss: 0.27313223481178284
# Epoch [1/5], BatchStep[0/64], Loss: 0.22842663526535034
# Epoch [1/5], BatchStep[0/64], Loss: 0.22799019515514374
# Epoch [1/5], BatchStep[0/64], Loss: 0.22845487296581268
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730978727340698
# Epoch [1/5], BatchStep[0/64], Loss: 0.22843487560749054
# Epoch [1/5], BatchStep[0/64], Loss: 0.22798509895801544
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730218470096588
# Epoch [1/5], BatchStep[0/64], Loss: 0.27291038632392883
# Epoch [1/5], BatchStep[0/64], Loss: 0.22781723737716675
# Epoch [1/5], BatchStep[0/64], Loss: 0.2272142618894577
# Epoch [1/5], BatchStep[0/64], Loss: 0.2274761199951172
# Epoch [1/5], BatchStep[0/64], Loss: 0.273037314414978
# Epoch [1/5], BatchStep[0/64], Loss: 0.22841134667396545
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730162441730499
# Epoch [1/5], BatchStep[0/64], Loss: 0.272959440946579
# Epoch [1/5], BatchStep[0/64], Loss: 0.22843441367149353
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276182472705841
# Epoch [1/5], BatchStep[0/64], Loss: 0.22817115485668182
# Epoch [1/5], BatchStep[0/64], Loss: 0.22723068296909332
# Epoch [1/5], BatchStep[0/64], Loss: 0.2272769659757614
# Epoch [1/5], BatchStep[0/64], Loss: 0.22809186577796936
# Epoch [1/5], BatchStep[0/64], Loss: 0.27325624227523804
# Epoch [1/5], BatchStep[0/64], Loss: 0.2732445299625397
# Epoch [1/5], BatchStep[0/64], Loss: 0.22773884236812592
# Epoch [1/5], BatchStep[0/64], Loss: 0.22768163681030273
# Epoch [1/5], BatchStep[0/64], Loss: 0.27291783690452576
# Epoch [1/5], BatchStep[0/64], Loss: 0.2278498411178589
# Epoch [1/5], BatchStep[0/64], Loss: 0.22743873298168182
# Epoch [1/5], BatchStep[0/64], Loss: 0.22703629732131958
# Epoch [1/5], BatchStep[0/64], Loss: 0.2273351103067398
# Epoch [1/5], BatchStep[0/64], Loss: 0.22825297713279724
# Epoch [1/5], BatchStep[0/64], Loss: 0.22786328196525574
# Epoch [1/5], BatchStep[0/64], Loss: 0.2272787243127823
# Epoch [1/5], BatchStep[0/64], Loss: 0.22687770426273346
# Epoch [1/5], BatchStep[0/64], Loss: 0.22734074294567108
# Epoch [1/5], BatchStep[0/64], Loss: 0.22708801925182343
# Epoch [1/5], BatchStep[0/64], Loss: 0.22789466381072998
# Epoch [1/5], BatchStep[0/64], Loss: 0.22818832099437714
# Epoch [1/5], BatchStep[0/64], Loss: 0.2280801385641098
# Epoch [1/5], BatchStep[0/64], Loss: 0.22771123051643372
# Epoch [1/5], BatchStep[0/64], Loss: 0.22771355509757996
# Epoch [1/5], BatchStep[0/64], Loss: 0.22708778083324432
# Epoch [1/5], BatchStep[0/64], Loss: 0.22815275192260742
# Epoch [1/5], BatchStep[0/64], Loss: 0.22814537584781647
# Epoch [1/5], BatchStep[0/64], Loss: 0.22776184976100922
# Epoch [1/5], BatchStep[0/64], Loss: 0.22792460024356842
# Epoch [1/5], BatchStep[0/64], Loss: 0.273110568523407
# Epoch [1/5], BatchStep[0/64], Loss: 0.22718596458435059
# Epoch [1/5], BatchStep[0/64], Loss: 0.22759215533733368
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731621563434601
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729661166667938
# Epoch [1/5], BatchStep[0/64], Loss: 0.22841894626617432
# Epoch [1/5], BatchStep[0/64], Loss: 0.2274179905653
# Epoch [1/5], BatchStep[0/64], Loss: 0.22784195840358734
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730742394924164
# Epoch [1/5], BatchStep[0/64], Loss: 0.22844600677490234
# Epoch [1/5], BatchStep[0/64], Loss: 0.2271866351366043
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276286631822586
# Epoch [1/5], BatchStep[0/64], Loss: 0.22731590270996094
# Epoch [1/5], BatchStep[0/64], Loss: 0.27306845784187317
# Epoch [1/5], BatchStep[0/64], Loss: 0.273041307926178
# Epoch [1/5], BatchStep[0/64], Loss: 0.22791998088359833
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275737226009369
# Epoch [1/5], BatchStep[0/64], Loss: 0.22682856023311615
# Epoch [1/5], BatchStep[0/64], Loss: 0.2274499088525772
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730265259742737
# Epoch [1/5], BatchStep[0/64], Loss: 0.22728699445724487
# Epoch [1/5], BatchStep[0/64], Loss: 0.22786585986614227
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730289697647095
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730521261692047
# Epoch [1/5], BatchStep[0/64], Loss: 0.22766529023647308
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730295956134796
# Epoch [1/5], BatchStep[0/64], Loss: 0.22723281383514404
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730574905872345
# Epoch [1/5], BatchStep[0/64], Loss: 0.2279364913702011
# Epoch [1/5], BatchStep[0/64], Loss: 0.27308931946754456
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730644643306732
# Epoch [1/5], BatchStep[0/64], Loss: 0.22831466794013977
# Epoch [1/5], BatchStep[0/64], Loss: 0.22761088609695435
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730328142642975
# Epoch [1/5], BatchStep[0/64], Loss: 0.27301400899887085
# Epoch [1/5], BatchStep[0/64], Loss: 0.22602792084217072
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731029689311981
# Epoch [1/5], BatchStep[0/64], Loss: 0.22780375182628632
# Epoch [1/5], BatchStep[0/64], Loss: 0.22785994410514832
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730071544647217
# Epoch [1/5], BatchStep[0/64], Loss: 0.22754816710948944
# Epoch [1/5], BatchStep[0/64], Loss: 0.2271573841571808
# Epoch [1/5], BatchStep[0/64], Loss: 0.22772200405597687
# Epoch [1/5], BatchStep[0/64], Loss: 0.27303919196128845
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731589078903198
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276328057050705
# Epoch [1/5], BatchStep[0/64], Loss: 0.27303096652030945
# Epoch [1/5], BatchStep[0/64], Loss: 0.2270752638578415
# Epoch [1/5], BatchStep[0/64], Loss: 0.22756414115428925
# Epoch [1/5], BatchStep[0/64], Loss: 0.22692762315273285
# Epoch [1/5], BatchStep[0/64], Loss: 0.2250073403120041
# Epoch [1/5], BatchStep[0/64], Loss: 0.27301549911499023
# Epoch [1/5], BatchStep[0/64], Loss: 0.22821420431137085
# Epoch [1/5], BatchStep[0/64], Loss: 0.22804158926010132
# Epoch [1/5], BatchStep[0/64], Loss: 0.22823862731456757
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729419469833374
# Epoch [1/5], BatchStep[0/64], Loss: 0.2273000180721283
# Epoch [1/5], BatchStep[0/64], Loss: 0.22781141102313995
# Epoch [1/5], BatchStep[0/64], Loss: 0.22748234868049622
# Epoch [1/5], BatchStep[0/64], Loss: 0.22766585648059845
# Epoch [1/5], BatchStep[0/64], Loss: 0.2278713583946228
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275795191526413
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729318141937256
# Epoch [1/5], BatchStep[0/64], Loss: 0.22741079330444336
# Epoch [1/5], BatchStep[0/64], Loss: 0.22742636501789093
# Epoch [1/5], BatchStep[0/64], Loss: 0.27309486269950867
# Epoch [1/5], BatchStep[0/64], Loss: 0.22733952105045319
# Epoch [1/5], BatchStep[0/64], Loss: 0.22843210399150848
# Epoch [1/5], BatchStep[0/64], Loss: 0.2273559421300888
# Epoch [1/5], BatchStep[0/64], Loss: 0.22823572158813477
# Epoch [1/5], BatchStep[0/64], Loss: 0.22844669222831726
# Epoch [1/5], BatchStep[0/64], Loss: 0.22779203951358795
# Epoch [1/5], BatchStep[0/64], Loss: 0.22761660814285278
# Epoch [1/5], BatchStep[0/64], Loss: 0.22778591513633728
# Epoch [1/5], BatchStep[0/64], Loss: 0.22814495861530304
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730177640914917
# Epoch [1/5], BatchStep[0/64], Loss: 0.22760045528411865
# Epoch [1/5], BatchStep[0/64], Loss: 0.22831591963768005
# Epoch [1/5], BatchStep[0/64], Loss: 0.22725290060043335
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730323374271393
# Epoch [1/5], BatchStep[0/64], Loss: 0.27304452657699585
# Epoch [1/5], BatchStep[0/64], Loss: 0.22703038156032562
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729990780353546
# Epoch [1/5], BatchStep[0/64], Loss: 0.2280399352312088
# Epoch [1/5], BatchStep[0/64], Loss: 0.22716055810451508
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729160487651825
# Epoch [1/5], BatchStep[0/64], Loss: 0.27305325865745544
# Epoch [1/5], BatchStep[0/64], Loss: 0.22763276100158691
# Epoch [1/5], BatchStep[0/64], Loss: 0.22793592512607574
# Epoch [1/5], BatchStep[0/64], Loss: 0.22810962796211243
# Epoch [1/5], BatchStep[0/64], Loss: 0.22754506766796112
# Epoch [1/5], BatchStep[0/64], Loss: 0.22834020853042603
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276168018579483
# Epoch [1/5], BatchStep[0/64], Loss: 0.22669187188148499
# Epoch [1/5], BatchStep[0/64], Loss: 0.22664879262447357
# Epoch [1/5], BatchStep[0/64], Loss: 0.22830113768577576
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282831370830536
# Epoch [1/5], BatchStep[0/64], Loss: 0.2277272343635559
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729388475418091
# Epoch [1/5], BatchStep[0/64], Loss: 0.228401318192482
# Epoch [1/5], BatchStep[0/64], Loss: 0.22770340740680695
# Epoch [1/5], BatchStep[0/64], Loss: 0.22787895798683167
# Epoch [1/5], BatchStep[0/64], Loss: 0.22751611471176147
# Epoch [1/5], BatchStep[0/64], Loss: 0.2263047695159912
# Epoch [1/5], BatchStep[0/64], Loss: 0.27318239212036133
# Epoch [1/5], BatchStep[0/64], Loss: 0.22800575196743011
# Epoch [1/5], BatchStep[0/64], Loss: 0.27310869097709656
# Epoch [1/5], BatchStep[0/64], Loss: 0.22698451578617096
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275722175836563
# Epoch [1/5], BatchStep[0/64], Loss: 0.2271132916212082
# Epoch [1/5], BatchStep[0/64], Loss: 0.2263375222682953
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275359332561493
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731894552707672
# Epoch [1/5], BatchStep[0/64], Loss: 0.22721567749977112
# Epoch [1/5], BatchStep[0/64], Loss: 0.22759360074996948
# Epoch [1/5], BatchStep[0/64], Loss: 0.22780841588974
# Epoch [1/5], BatchStep[0/64], Loss: 0.2283310443162918
# Epoch [1/5], BatchStep[0/64], Loss: 0.27311256527900696
# Epoch [1/5], BatchStep[0/64], Loss: 0.22773386538028717
# Epoch [1/5], BatchStep[0/64], Loss: 0.22824184596538544
# Epoch [1/5], BatchStep[0/64], Loss: 0.273037314414978
# Epoch [1/5], BatchStep[0/64], Loss: 0.27295950055122375
# Epoch [1/5], BatchStep[0/64], Loss: 0.22720646858215332
# Epoch [1/5], BatchStep[0/64], Loss: 0.27310696244239807
# Epoch [1/5], BatchStep[0/64], Loss: 0.22708335518836975
# Epoch [1/5], BatchStep[0/64], Loss: 0.273088276386261
# Epoch [1/5], BatchStep[0/64], Loss: 0.22738541662693024
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730724513530731
# Epoch [1/5], BatchStep[0/64], Loss: 0.22812263667583466
# Epoch [1/5], BatchStep[0/64], Loss: 0.27307194471359253
# Epoch [1/5], BatchStep[0/64], Loss: 0.22712764143943787
# Epoch [1/5], BatchStep[0/64], Loss: 0.27310410141944885
# Epoch [1/5], BatchStep[0/64], Loss: 0.22832557559013367
# Epoch [1/5], BatchStep[0/64], Loss: 0.22793449461460114
# Epoch [1/5], BatchStep[0/64], Loss: 0.22785824537277222
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729884684085846
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275780737400055
# Epoch [1/5], BatchStep[0/64], Loss: 0.27292463183403015
# Epoch [1/5], BatchStep[0/64], Loss: 0.22807814180850983
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730642259120941
# Epoch [1/5], BatchStep[0/64], Loss: 0.22837841510772705
# Epoch [1/5], BatchStep[0/64], Loss: 0.27302584052085876
# Epoch [1/5], BatchStep[0/64], Loss: 0.22701852023601532
# Epoch [1/5], BatchStep[0/64], Loss: 0.27307742834091187
# Epoch [1/5], BatchStep[0/64], Loss: 0.22798950970172882
# Epoch [1/5], BatchStep[0/64], Loss: 0.22770372033119202
# Epoch [1/5], BatchStep[0/64], Loss: 0.22844429314136505
# Epoch [1/5], BatchStep[0/64], Loss: 0.2272094339132309
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730461657047272
# Epoch [1/5], BatchStep[0/64], Loss: 0.27305999398231506
# Epoch [1/5], BatchStep[0/64], Loss: 0.27301961183547974
# Epoch [1/5], BatchStep[0/64], Loss: 0.22760716080665588
# Epoch [1/5], BatchStep[0/64], Loss: 0.27300652861595154
# Epoch [1/5], BatchStep[0/64], Loss: 0.22670097649097443
# Epoch [1/5], BatchStep[0/64], Loss: 0.22786259651184082
# Epoch [1/5], BatchStep[0/64], Loss: 0.22771164774894714
# Epoch [1/5], BatchStep[0/64], Loss: 0.273094117641449
# Epoch [1/5], BatchStep[0/64], Loss: 0.2278391271829605
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730695903301239
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284281998872757
# Epoch [1/5], BatchStep[0/64], Loss: 0.226148784160614
# Epoch [1/5], BatchStep[0/64], Loss: 0.27293965220451355
# Epoch [1/5], BatchStep[0/64], Loss: 0.22842788696289062
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730230987071991
# Epoch [1/5], BatchStep[0/64], Loss: 0.22785590589046478
# Epoch [1/5], BatchStep[0/64], Loss: 0.22792623937129974
# Epoch [1/5], BatchStep[0/64], Loss: 0.2277790606021881
# Epoch [1/5], BatchStep[0/64], Loss: 0.22806590795516968
# Epoch [1/5], BatchStep[0/64], Loss: 0.22766879200935364
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730865776538849
# Epoch [1/5], BatchStep[0/64], Loss: 0.273097425699234
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729649245738983
# Epoch [1/5], BatchStep[0/64], Loss: 0.22763264179229736
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730480134487152
# Epoch [1/5], BatchStep[0/64], Loss: 0.22833870351314545
# Epoch [1/5], BatchStep[0/64], Loss: 0.22728946805000305
# Epoch [1/5], BatchStep[0/64], Loss: 0.22772425413131714
# Epoch [1/5], BatchStep[0/64], Loss: 0.22806313633918762
# Epoch [1/5], BatchStep[0/64], Loss: 0.22698338329792023
# Epoch [1/5], BatchStep[0/64], Loss: 0.22778208553791046
# Epoch [1/5], BatchStep[0/64], Loss: 0.22734716534614563
# Epoch [1/5], BatchStep[0/64], Loss: 0.27305611968040466
# Epoch [1/5], BatchStep[0/64], Loss: 0.2274215966463089
# Epoch [1/5], BatchStep[0/64], Loss: 0.27298006415367126
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731768488883972
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731301188468933
# Epoch [1/5], BatchStep[0/64], Loss: 0.22827760875225067
# Epoch [1/5], BatchStep[0/64], Loss: 0.27310433983802795
# Epoch [1/5], BatchStep[0/64], Loss: 0.22837023437023163
# Epoch [1/5], BatchStep[0/64], Loss: 0.22845318913459778
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729029059410095
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284444123506546
# Epoch [1/5], BatchStep[0/64], Loss: 0.27294424176216125
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276734560728073
# Epoch [1/5], BatchStep[0/64], Loss: 0.22695860266685486
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730814814567566
# Epoch [1/5], BatchStep[0/64], Loss: 0.2272184044122696
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729913294315338
# Epoch [1/5], BatchStep[0/64], Loss: 0.22668151557445526
# Epoch [1/5], BatchStep[0/64], Loss: 0.27307605743408203
# Epoch [1/5], BatchStep[0/64], Loss: 0.22673654556274414
# Epoch [1/5], BatchStep[0/64], Loss: 0.22847361862659454
# Epoch [1/5], BatchStep[0/64], Loss: 0.22818991541862488
# Epoch [1/5], BatchStep[0/64], Loss: 0.22798489034175873
# Epoch [1/5], BatchStep[0/64], Loss: 0.2279464453458786
# Epoch [1/5], BatchStep[0/64], Loss: 0.22768744826316833
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276660054922104
# Epoch [1/5], BatchStep[0/64], Loss: 0.27307915687561035
# Epoch [1/5], BatchStep[0/64], Loss: 0.22668465971946716
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276718020439148
# Epoch [1/5], BatchStep[0/64], Loss: 0.22751833498477936
# Epoch [1/5], BatchStep[0/64], Loss: 0.22808314859867096
# Epoch [1/5], BatchStep[0/64], Loss: 0.22780466079711914
# Epoch [1/5], BatchStep[0/64], Loss: 0.22737078368663788
# Epoch [1/5], BatchStep[0/64], Loss: 0.22709724307060242
# Epoch [1/5], BatchStep[0/64], Loss: 0.272998571395874
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731524407863617
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282412201166153
# Epoch [1/5], BatchStep[0/64], Loss: 0.2267734855413437
# Epoch [1/5], BatchStep[0/64], Loss: 0.227204829454422
# Epoch [1/5], BatchStep[0/64], Loss: 0.22766517102718353
# Epoch [1/5], BatchStep[0/64], Loss: 0.22745485603809357
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729478180408478
# Epoch [1/5], BatchStep[0/64], Loss: 0.22787781059741974
# Epoch [1/5], BatchStep[0/64], Loss: 0.22781752049922943
# Epoch [1/5], BatchStep[0/64], Loss: 0.22820357978343964
# Epoch [1/5], BatchStep[0/64], Loss: 0.22774143517017365
# Epoch [1/5], BatchStep[0/64], Loss: 0.22754961252212524
# Epoch [1/5], BatchStep[0/64], Loss: 0.22799932956695557
# Epoch [1/5], BatchStep[0/64], Loss: 0.27311164140701294
# Epoch [1/5], BatchStep[0/64], Loss: 0.2268640547990799
# Epoch [1/5], BatchStep[0/64], Loss: 0.273002564907074
# Epoch [1/5], BatchStep[0/64], Loss: 0.27301526069641113
# Epoch [1/5], BatchStep[0/64], Loss: 0.27300530672073364
# Epoch [1/5], BatchStep[0/64], Loss: 0.22774040699005127
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729915976524353
# Epoch [1/5], BatchStep[0/64], Loss: 0.2271420955657959
# Epoch [1/5], BatchStep[0/64], Loss: 0.27305474877357483
# Epoch [1/5], BatchStep[0/64], Loss: 0.22756880521774292
# Epoch [1/5], BatchStep[0/64], Loss: 0.22778631746768951
# Epoch [1/5], BatchStep[0/64], Loss: 0.227275550365448
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730582356452942
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275039553642273
# Epoch [1/5], BatchStep[0/64], Loss: 0.27303194999694824
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730728089809418
# Epoch [1/5], BatchStep[0/64], Loss: 0.22758981585502625
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282809466123581
# Epoch [1/5], BatchStep[0/64], Loss: 0.22666709125041962
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730545103549957
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730041742324829
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730548679828644
# Epoch [1/5], BatchStep[0/64], Loss: 0.22786901891231537
# Epoch [1/5], BatchStep[0/64], Loss: 0.27303144335746765
# Epoch [1/5], BatchStep[0/64], Loss: 0.27293553948402405
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730560004711151
# Epoch [1/5], BatchStep[0/64], Loss: 0.22826960682868958
# Epoch [1/5], BatchStep[0/64], Loss: 0.22761353850364685
# Epoch [1/5], BatchStep[0/64], Loss: 0.273222953081131
# Epoch [1/5], BatchStep[0/64], Loss: 0.22785280644893646
# Epoch [1/5], BatchStep[0/64], Loss: 0.2273193895816803
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731468379497528
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730900049209595
# Epoch [1/5], BatchStep[0/64], Loss: 0.22707702219486237
# Epoch [1/5], BatchStep[0/64], Loss: 0.2733498513698578
# Epoch [1/5], BatchStep[0/64], Loss: 0.22788631916046143
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730589210987091
# Epoch [1/5], BatchStep[0/64], Loss: 0.22771380841732025
# Epoch [1/5], BatchStep[0/64], Loss: 0.27302297949790955
# Epoch [1/5], BatchStep[0/64], Loss: 0.22842039167881012
# Epoch [1/5], BatchStep[0/64], Loss: 0.22779057919979095
# Epoch [1/5], BatchStep[0/64], Loss: 0.22810037434101105
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730409801006317
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731459438800812
# Epoch [1/5], BatchStep[0/64], Loss: 0.2279757559299469
# Epoch [1/5], BatchStep[0/64], Loss: 0.27293702960014343
# Epoch [1/5], BatchStep[0/64], Loss: 0.272970050573349
# Epoch [1/5], BatchStep[0/64], Loss: 0.22764995694160461
# Epoch [1/5], BatchStep[0/64], Loss: 0.22732359170913696
# Epoch [1/5], BatchStep[0/64], Loss: 0.22825193405151367
# Epoch [1/5], BatchStep[0/64], Loss: 0.22822415828704834
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729156017303467
# Epoch [1/5], BatchStep[0/64], Loss: 0.27314072847366333
# Epoch [1/5], BatchStep[0/64], Loss: 0.22682444751262665
# Epoch [1/5], BatchStep[0/64], Loss: 0.22792522609233856
# Epoch [1/5], BatchStep[0/64], Loss: 0.22841139137744904
# Epoch [1/5], BatchStep[0/64], Loss: 0.22819948196411133
# Epoch [1/5], BatchStep[0/64], Loss: 0.2278839647769928
# Epoch [1/5], BatchStep[0/64], Loss: 0.22735588252544403
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729879915714264
# Epoch [1/5], BatchStep[0/64], Loss: 0.22833573818206787
# Epoch [1/5], BatchStep[0/64], Loss: 0.2273310422897339
# Epoch [1/5], BatchStep[0/64], Loss: 0.2266751229763031
# Epoch [1/5], BatchStep[0/64], Loss: 0.27308377623558044
# Epoch [1/5], BatchStep[0/64], Loss: 0.27304890751838684
# Epoch [1/5], BatchStep[0/64], Loss: 0.22776290774345398
# Epoch [1/5], BatchStep[0/64], Loss: 0.2273571938276291
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731275260448456
# Epoch [1/5], BatchStep[0/64], Loss: 0.22832725942134857
# Epoch [1/5], BatchStep[0/64], Loss: 0.22762741148471832
# Epoch [1/5], BatchStep[0/64], Loss: 0.227339968085289
# Epoch [1/5], BatchStep[0/64], Loss: 0.22666442394256592
# Epoch [1/5], BatchStep[0/64], Loss: 0.2280864268541336
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275233119726181
# Epoch [1/5], BatchStep[0/64], Loss: 0.27309662103652954
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730637192726135
# Epoch [1/5], BatchStep[0/64], Loss: 0.22802597284317017
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282879799604416
# Epoch [1/5], BatchStep[0/64], Loss: 0.22747521102428436
# Epoch [1/5], BatchStep[0/64], Loss: 0.2277408391237259
# Epoch [1/5], BatchStep[0/64], Loss: 0.2280779480934143
# Epoch [1/5], BatchStep[0/64], Loss: 0.22757641971111298
# Epoch [1/5], BatchStep[0/64], Loss: 0.27299967408180237
# Epoch [1/5], BatchStep[0/64], Loss: 0.22827106714248657
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731034755706787
# Epoch [1/5], BatchStep[0/64], Loss: 0.27305537462234497
# Epoch [1/5], BatchStep[0/64], Loss: 0.2267996072769165
# Epoch [1/5], BatchStep[0/64], Loss: 0.22794634103775024
# Epoch [1/5], BatchStep[0/64], Loss: 0.22709037363529205
# Epoch [1/5], BatchStep[0/64], Loss: 0.2283441126346588
# Epoch [1/5], BatchStep[0/64], Loss: 0.22842296957969666
# Epoch [1/5], BatchStep[0/64], Loss: 0.22739212214946747
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731750011444092
# Epoch [1/5], BatchStep[0/64], Loss: 0.22777564823627472
# Epoch [1/5], BatchStep[0/64], Loss: 0.22748905420303345
# Epoch [1/5], BatchStep[0/64], Loss: 0.27302297949790955
# Epoch [1/5], BatchStep[0/64], Loss: 0.22822624444961548
# Epoch [1/5], BatchStep[0/64], Loss: 0.22733990848064423
# Epoch [1/5], BatchStep[0/64], Loss: 0.2281164824962616
# Epoch [1/5], BatchStep[0/64], Loss: 0.22815722227096558
# Epoch [1/5], BatchStep[0/64], Loss: 0.22815074026584625
# Epoch [1/5], BatchStep[0/64], Loss: 0.22737936675548553
# Epoch [1/5], BatchStep[0/64], Loss: 0.22811415791511536
# Epoch [1/5], BatchStep[0/64], Loss: 0.228419691324234
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730584144592285
# Epoch [1/5], BatchStep[0/64], Loss: 0.22785684466362
# Epoch [1/5], BatchStep[0/64], Loss: 0.22843581438064575
# Epoch [1/5], BatchStep[0/64], Loss: 0.22787007689476013
# Epoch [1/5], BatchStep[0/64], Loss: 0.22754350304603577
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282610982656479
# Epoch [1/5], BatchStep[0/64], Loss: 0.22844737768173218
# Epoch [1/5], BatchStep[0/64], Loss: 0.27303457260131836
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730341851711273
# Epoch [1/5], BatchStep[0/64], Loss: 0.22738836705684662
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730768620967865
# Epoch [1/5], BatchStep[0/64], Loss: 0.27318596839904785
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730654776096344
# Epoch [1/5], BatchStep[0/64], Loss: 0.22739243507385254
# Epoch [1/5], BatchStep[0/64], Loss: 0.22774899005889893
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284269481897354
# Epoch [1/5], BatchStep[0/64], Loss: 0.22796320915222168
# Epoch [1/5], BatchStep[0/64], Loss: 0.22792641818523407
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730206251144409
# Epoch [1/5], BatchStep[0/64], Loss: 0.228067547082901
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731062173843384
# Epoch [1/5], BatchStep[0/64], Loss: 0.22742873430252075
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730962932109833
# Epoch [1/5], BatchStep[0/64], Loss: 0.22689667344093323
# Epoch [1/5], BatchStep[0/64], Loss: 0.22709554433822632
# Epoch [1/5], BatchStep[0/64], Loss: 0.22846205532550812
# Epoch [1/5], BatchStep[0/64], Loss: 0.227699875831604
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730517089366913
# Epoch [1/5], BatchStep[0/64], Loss: 0.22843976318836212
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730121314525604
# Epoch [1/5], BatchStep[0/64], Loss: 0.22779619693756104
# Epoch [1/5], BatchStep[0/64], Loss: 0.22825859487056732
# Epoch [1/5], BatchStep[0/64], Loss: 0.22783155739307404
# Epoch [1/5], BatchStep[0/64], Loss: 0.22714127600193024
# Epoch [1/5], BatchStep[0/64], Loss: 0.27303406596183777
# Epoch [1/5], BatchStep[0/64], Loss: 0.2278706431388855
# Epoch [1/5], BatchStep[0/64], Loss: 0.22699442505836487
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730649709701538
# Epoch [1/5], BatchStep[0/64], Loss: 0.22782161831855774
# Epoch [1/5], BatchStep[0/64], Loss: 0.22775226831436157
# Epoch [1/5], BatchStep[0/64], Loss: 0.22770880162715912
# Epoch [1/5], BatchStep[0/64], Loss: 0.22843623161315918
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730640470981598
# Epoch [1/5], BatchStep[0/64], Loss: 0.27296778559684753
# Epoch [1/5], BatchStep[0/64], Loss: 0.22826765477657318
# Epoch [1/5], BatchStep[0/64], Loss: 0.22677263617515564
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730877697467804
# Epoch [1/5], BatchStep[0/64], Loss: 0.27295011281967163
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282274067401886
# Epoch [1/5], BatchStep[0/64], Loss: 0.27306583523750305
# Epoch [1/5], BatchStep[0/64], Loss: 0.2274371236562729
# Epoch [1/5], BatchStep[0/64], Loss: 0.2268473207950592
# Epoch [1/5], BatchStep[0/64], Loss: 0.22770501673221588
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284068614244461
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730288505554199
# Epoch [1/5], BatchStep[0/64], Loss: 0.22708551585674286
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729812562465668
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275581955909729
# Epoch [1/5], BatchStep[0/64], Loss: 0.2268044650554657
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730809152126312
# Epoch [1/5], BatchStep[0/64], Loss: 0.27304503321647644
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284364402294159
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730419337749481
# Epoch [1/5], BatchStep[0/64], Loss: 0.27301886677742004
# Epoch [1/5], BatchStep[0/64], Loss: 0.27310696244239807
# Epoch [1/5], BatchStep[0/64], Loss: 0.273049533367157
# Epoch [1/5], BatchStep[0/64], Loss: 0.27299270033836365
# Epoch [1/5], BatchStep[0/64], Loss: 0.22836564481258392
# Epoch [1/5], BatchStep[0/64], Loss: 0.22764068841934204
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730039358139038
# Epoch [1/5], BatchStep[0/64], Loss: 0.22846537828445435
# Epoch [1/5], BatchStep[0/64], Loss: 0.2733273506164551
# Epoch [1/5], BatchStep[0/64], Loss: 0.2732020914554596
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282567173242569
# Epoch [1/5], BatchStep[0/64], Loss: 0.22673526406288147
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730838358402252
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276129573583603
# Epoch [1/5], BatchStep[0/64], Loss: 0.22736898064613342
# Epoch [1/5], BatchStep[0/64], Loss: 0.27293503284454346
# Epoch [1/5], BatchStep[0/64], Loss: 0.22704796493053436
# Epoch [1/5], BatchStep[0/64], Loss: 0.22728730738162994
# Epoch [1/5], BatchStep[0/64], Loss: 0.22830228507518768
# Epoch [1/5], BatchStep[0/64], Loss: 0.22759464383125305
# Epoch [1/5], BatchStep[0/64], Loss: 0.27317363023757935
# Epoch [1/5], BatchStep[0/64], Loss: 0.22841717302799225
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276904582977295
# Epoch [1/5], BatchStep[0/64], Loss: 0.22826316952705383
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729722857475281
# Epoch [1/5], BatchStep[0/64], Loss: 0.27312371134757996
# Epoch [1/5], BatchStep[0/64], Loss: 0.22804059088230133
# Epoch [1/5], BatchStep[0/64], Loss: 0.22836658358573914
# Epoch [1/5], BatchStep[0/64], Loss: 0.22725878655910492
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730085849761963
# Epoch [1/5], BatchStep[0/64], Loss: 0.22799839079380035
# Epoch [1/5], BatchStep[0/64], Loss: 0.2278851568698883
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729649245738983
# Epoch [1/5], BatchStep[0/64], Loss: 0.22769026458263397
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284424751996994
# Epoch [1/5], BatchStep[0/64], Loss: 0.22739988565444946
# Epoch [1/5], BatchStep[0/64], Loss: 0.22769947350025177
# Epoch [1/5], BatchStep[0/64], Loss: 0.22742021083831787
# Epoch [1/5], BatchStep[0/64], Loss: 0.27310794591903687
# Epoch [1/5], BatchStep[0/64], Loss: 0.22816716134548187
# Epoch [1/5], BatchStep[0/64], Loss: 0.22775958478450775
# Epoch [1/5], BatchStep[0/64], Loss: 0.22775496542453766
# Epoch [1/5], BatchStep[0/64], Loss: 0.22736665606498718
# Epoch [1/5], BatchStep[0/64], Loss: 0.2279045581817627
# Epoch [1/5], BatchStep[0/64], Loss: 0.22729350626468658
# Epoch [1/5], BatchStep[0/64], Loss: 0.22756336629390717
# Epoch [1/5], BatchStep[0/64], Loss: 0.2279563546180725
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731029689311981
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276024967432022
# Epoch [1/5], BatchStep[0/64], Loss: 0.22744058072566986
# Epoch [1/5], BatchStep[0/64], Loss: 0.22718195617198944
# Epoch [1/5], BatchStep[0/64], Loss: 0.22761981189250946
# Epoch [1/5], BatchStep[0/64], Loss: 0.22734685242176056
# Epoch [1/5], BatchStep[0/64], Loss: 0.27300503849983215
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729988098144531
# Epoch [1/5], BatchStep[0/64], Loss: 0.22780120372772217
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730506956577301
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730102837085724
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730976641178131
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730218470096588
# Epoch [1/5], BatchStep[0/64], Loss: 0.22740758955478668
# Epoch [1/5], BatchStep[0/64], Loss: 0.27303624153137207
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730499505996704
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729938328266144
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730071544647217
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282894402742386
# Epoch [1/5], BatchStep[0/64], Loss: 0.27314427495002747
# Epoch [1/5], BatchStep[0/64], Loss: 0.22728577256202698
# Epoch [1/5], BatchStep[0/64], Loss: 0.22791831195354462
# Epoch [1/5], BatchStep[0/64], Loss: 0.22759754955768585
# Epoch [1/5], BatchStep[0/64], Loss: 0.2279367446899414
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730754315853119
# Epoch [1/5], BatchStep[0/64], Loss: 0.22683671116828918
# Epoch [1/5], BatchStep[0/64], Loss: 0.22792012989521027
# Epoch [1/5], BatchStep[0/64], Loss: 0.27310046553611755
# Epoch [1/5], BatchStep[0/64], Loss: 0.22780174016952515
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730439007282257
# Epoch [1/5], BatchStep[0/64], Loss: 0.227278470993042
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730625867843628
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284134179353714
# Epoch [1/5], BatchStep[0/64], Loss: 0.22699318826198578
# Epoch [1/5], BatchStep[0/64], Loss: 0.22773471474647522
# Epoch [1/5], BatchStep[0/64], Loss: 0.22791047394275665
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730598449707031
# Epoch [1/5], BatchStep[0/64], Loss: 0.22779589891433716
# Epoch [1/5], BatchStep[0/64], Loss: 0.2279125601053238
# Epoch [1/5], BatchStep[0/64], Loss: 0.22825725376605988
# Epoch [1/5], BatchStep[0/64], Loss: 0.22841863334178925
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730577290058136
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731027901172638
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730943560600281
# Epoch [1/5], BatchStep[0/64], Loss: 0.22770792245864868
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730630934238434
# Epoch [1/5], BatchStep[0/64], Loss: 0.27302679419517517
# Epoch [1/5], BatchStep[0/64], Loss: 0.22793211042881012
# Epoch [1/5], BatchStep[0/64], Loss: 0.2274700403213501
# Epoch [1/5], BatchStep[0/64], Loss: 0.2279178500175476
# Epoch [1/5], BatchStep[0/64], Loss: 0.22841843962669373
# Epoch [1/5], BatchStep[0/64], Loss: 0.27308040857315063
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730642259120941
# Epoch [1/5], BatchStep[0/64], Loss: 0.22731471061706543
# Epoch [1/5], BatchStep[0/64], Loss: 0.27313485741615295
# Epoch [1/5], BatchStep[0/64], Loss: 0.22755840420722961
# Epoch [1/5], BatchStep[0/64], Loss: 0.27303555607795715
# Epoch [1/5], BatchStep[0/64], Loss: 0.228285014629364
# Epoch [1/5], BatchStep[0/64], Loss: 0.272968053817749
# Epoch [1/5], BatchStep[0/64], Loss: 0.22841013967990875
# Epoch [1/5], BatchStep[0/64], Loss: 0.22779613733291626
# Epoch [1/5], BatchStep[0/64], Loss: 0.22759902477264404
# Epoch [1/5], BatchStep[0/64], Loss: 0.2271140068769455
# Epoch [1/5], BatchStep[0/64], Loss: 0.22708997130393982
# Epoch [1/5], BatchStep[0/64], Loss: 0.22723039984703064
# Epoch [1/5], BatchStep[0/64], Loss: 0.22732815146446228
# Epoch [1/5], BatchStep[0/64], Loss: 0.22803282737731934
# Epoch [1/5], BatchStep[0/64], Loss: 0.22762632369995117
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730282247066498
# Epoch [1/5], BatchStep[0/64], Loss: 0.22739337384700775
# Epoch [1/5], BatchStep[0/64], Loss: 0.22740145027637482
# Epoch [1/5], BatchStep[0/64], Loss: 0.22717110812664032
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730715572834015
# Epoch [1/5], BatchStep[0/64], Loss: 0.22801293432712555
# Epoch [1/5], BatchStep[0/64], Loss: 0.22715437412261963
# Epoch [1/5], BatchStep[0/64], Loss: 0.2283831387758255
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729829251766205
# Epoch [1/5], BatchStep[0/64], Loss: 0.2279461920261383
# Epoch [1/5], BatchStep[0/64], Loss: 0.2732096314430237
# Epoch [1/5], BatchStep[0/64], Loss: 0.27310457825660706
# Epoch [1/5], BatchStep[0/64], Loss: 0.22726556658744812
# Epoch [1/5], BatchStep[0/64], Loss: 0.22818291187286377
# Epoch [1/5], BatchStep[0/64], Loss: 0.22803007066249847
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729184627532959
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730725109577179
# Epoch [1/5], BatchStep[0/64], Loss: 0.227653369307518
# Epoch [1/5], BatchStep[0/64], Loss: 0.22781598567962646
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275862693786621
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731066942214966
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731386125087738
# Epoch [1/5], BatchStep[0/64], Loss: 0.22775869071483612
# Epoch [1/5], BatchStep[0/64], Loss: 0.2282678484916687
# Epoch [1/5], BatchStep[0/64], Loss: 0.2273818850517273
# Epoch [1/5], BatchStep[0/64], Loss: 0.22819733619689941
# Epoch [1/5], BatchStep[0/64], Loss: 0.22693823277950287
# Epoch [1/5], BatchStep[0/64], Loss: 0.2283412367105484
# Epoch [1/5], BatchStep[0/64], Loss: 0.22681289911270142
# Epoch [1/5], BatchStep[0/64], Loss: 0.22835591435432434
# Epoch [1/5], BatchStep[0/64], Loss: 0.2274862676858902
# Epoch [1/5], BatchStep[0/64], Loss: 0.22738996148109436
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730090916156769
# Epoch [1/5], BatchStep[0/64], Loss: 0.27301788330078125
# Epoch [1/5], BatchStep[0/64], Loss: 0.22725149989128113
# Epoch [1/5], BatchStep[0/64], Loss: 0.22770363092422485
# Epoch [1/5], BatchStep[0/64], Loss: 0.22788406908512115
# Epoch [1/5], BatchStep[0/64], Loss: 0.22817914187908173
# Epoch [1/5], BatchStep[0/64], Loss: 0.22748273611068726
# Epoch [1/5], BatchStep[0/64], Loss: 0.22749687731266022
# Epoch [1/5], BatchStep[0/64], Loss: 0.27305537462234497
# Epoch [1/5], BatchStep[0/64], Loss: 0.22769324481487274
# Epoch [1/5], BatchStep[0/64], Loss: 0.22795698046684265
# Epoch [1/5], BatchStep[0/64], Loss: 0.22830648720264435
# Epoch [1/5], BatchStep[0/64], Loss: 0.27304938435554504
# Epoch [1/5], BatchStep[0/64], Loss: 0.22834400832653046
# Epoch [1/5], BatchStep[0/64], Loss: 0.27314820885658264
# Epoch [1/5], BatchStep[0/64], Loss: 0.22784771025180817
# Epoch [1/5], BatchStep[0/64], Loss: 0.22781138122081757
# Epoch [1/5], BatchStep[0/64], Loss: 0.22757196426391602
# Epoch [1/5], BatchStep[0/64], Loss: 0.22807244956493378
# Epoch [1/5], BatchStep[0/64], Loss: 0.27300453186035156
# Epoch [1/5], BatchStep[0/64], Loss: 0.2276732474565506
# Epoch [1/5], BatchStep[0/64], Loss: 0.22737382352352142
# Epoch [1/5], BatchStep[0/64], Loss: 0.27309074997901917
# Epoch [1/5], BatchStep[0/64], Loss: 0.2280551940202713
# Epoch [1/5], BatchStep[0/64], Loss: 0.273105263710022
# Epoch [1/5], BatchStep[0/64], Loss: 0.22792838513851166
# Epoch [1/5], BatchStep[0/64], Loss: 0.27299755811691284
# Epoch [1/5], BatchStep[0/64], Loss: 0.2283608615398407
# Epoch [1/5], BatchStep[0/64], Loss: 0.22840698063373566
# Epoch [1/5], BatchStep[0/64], Loss: 0.22833532094955444
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730885148048401
# Epoch [1/5], BatchStep[0/64], Loss: 0.22699715197086334
# Epoch [1/5], BatchStep[0/64], Loss: 0.22743475437164307
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730172574520111
# Epoch [1/5], BatchStep[0/64], Loss: 0.228276789188385
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731149196624756
# Epoch [1/5], BatchStep[0/64], Loss: 0.22815722227096558
# Epoch [1/5], BatchStep[0/64], Loss: 0.22767199575901031
# Epoch [1/5], BatchStep[0/64], Loss: 0.22808875143527985
# Epoch [1/5], BatchStep[0/64], Loss: 0.22740837931632996
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730638384819031
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284512221813202
# Epoch [1/5], BatchStep[0/64], Loss: 0.22842800617218018
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730545103549957
# Epoch [1/5], BatchStep[0/64], Loss: 0.22727108001708984
# Epoch [1/5], BatchStep[0/64], Loss: 0.22683025896549225
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730860114097595
# Epoch [1/5], BatchStep[0/64], Loss: 0.22831504046916962
# Epoch [1/5], BatchStep[0/64], Loss: 0.272970050573349
# Epoch [1/5], BatchStep[0/64], Loss: 0.27309367060661316
# Epoch [1/5], BatchStep[0/64], Loss: 0.2265227884054184
# Epoch [1/5], BatchStep[0/64], Loss: 0.2275088131427765
# Epoch [1/5], BatchStep[0/64], Loss: 0.22810521721839905
# Epoch [1/5], BatchStep[0/64], Loss: 0.22799529135227203
# Epoch [1/5], BatchStep[0/64], Loss: 0.22736679017543793
# Epoch [1/5], BatchStep[0/64], Loss: 0.22689317166805267
# Epoch [1/5], BatchStep[0/64], Loss: 0.22839395701885223
# Epoch [1/5], BatchStep[0/64], Loss: 0.22763586044311523
# Epoch [1/5], BatchStep[0/64], Loss: 0.22798262536525726
# Epoch [1/5], BatchStep[0/64], Loss: 0.27305904030799866
# Epoch [1/5], BatchStep[0/64], Loss: 0.22784821689128876
# Epoch [1/5], BatchStep[0/64], Loss: 0.27322065830230713
# Epoch [1/5], BatchStep[0/64], Loss: 0.22704486548900604
# Epoch [1/5], BatchStep[0/64], Loss: 0.2274135798215866
# Epoch [1/5], BatchStep[0/64], Loss: 0.2277083843946457
# Epoch [1/5], BatchStep[0/64], Loss: 0.2272634357213974
# Epoch [1/5], BatchStep[0/64], Loss: 0.22738654911518097
# Epoch [1/5], BatchStep[0/64], Loss: 0.2278730273246765
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729935944080353
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284371703863144
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730467915534973
# Epoch [1/5], BatchStep[0/64], Loss: 0.27301153540611267
# Epoch [1/5], BatchStep[0/64], Loss: 0.27307698130607605
# Epoch [1/5], BatchStep[0/64], Loss: 0.22734425961971283
# Epoch [1/5], BatchStep[0/64], Loss: 0.22742503881454468
# Epoch [1/5], BatchStep[0/64], Loss: 0.2731006145477295
# Epoch [1/5], BatchStep[0/64], Loss: 0.27292296290397644
# Epoch [1/5], BatchStep[0/64], Loss: 0.27305319905281067
# Epoch [1/5], BatchStep[0/64], Loss: 0.22774860262870789
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730434834957123
# Epoch [1/5], BatchStep[0/64], Loss: 0.2281503677368164
# Epoch [1/5], BatchStep[0/64], Loss: 0.22730682790279388
# Epoch [1/5], BatchStep[0/64], Loss: 0.22725547850131989
# Epoch [1/5], BatchStep[0/64], Loss: 0.27308279275894165
# Epoch [1/5], BatchStep[0/64], Loss: 0.22843550145626068
# Epoch [1/5], BatchStep[0/64], Loss: 0.27304747700691223
# Epoch [1/5], BatchStep[0/64], Loss: 0.22826191782951355
# Epoch [1/5], BatchStep[0/64], Loss: 0.2284097671508789
# Epoch [1/5], BatchStep[0/64], Loss: 0.22801916301250458
# Epoch [1/5], BatchStep[0/64], Loss: 0.22643859684467316
# Epoch [1/5], BatchStep[0/64], Loss: 0.22741156816482544
# Epoch [1/5], BatchStep[0/64], Loss: 0.22737467288970947
# Epoch [1/5], BatchStep[0/64], Loss: 0.22734986245632172
# Epoch [1/5], BatchStep[0/64], Loss: 0.22781872749328613
# Epoch [1/5], BatchStep[0/64], Loss: 0.2729659974575043
# Epoch [1/5], BatchStep[0/64], Loss: 0.22846147418022156
# Epoch [1/5], BatchStep[0/64], Loss: 0.2730873227119446
# Epoch [1/5], BatchStep[0/64], Loss: 0.27302590012550354
# Epoch [1/5], BatchStep[0/64], Loss: 0.22755932807922363
# Epoch [1/5], BatchStep[1/64], Loss: 0.21325500309467316
# Epoch [1/5], BatchStep[1/64], Loss: 0.29025933146476746
# Epoch [1/5], BatchStep[1/64], Loss: 0.2902112901210785
# Epoch [1/5], BatchStep[1/64], Loss: 0.2901707589626312
# Epoch [1/5], BatchStep[1/64], Loss: 0.2899378538131714
# Epoch [1/5], BatchStep[1/64], Loss: 0.2114734947681427
# Epoch [1/5], BatchStep[1/64], Loss: 0.2899273931980133
# Epoch [1/5], BatchStep[1/64], Loss: 0.21347598731517792
# Epoch [1/5], BatchStep[1/64], Loss: 0.21021251380443573
# Epoch [1/5], BatchStep[1/64], Loss: 0.2101643681526184
# Epoch [1/5], BatchStep[1/64], Loss: 0.29006776213645935
# Epoch [1/5], BatchStep[1/64], Loss: 0.2902460992336273
# Epoch [1/5], BatchStep[1/64], Loss: 0.21389947831630707
# Epoch [1/5], BatchStep[1/64], Loss: 0.2903578579425812
# Epoch [1/5], BatchStep[1/64], Loss: 0.21117781102657318
# Epoch [1/5], BatchStep[1/64], Loss: 0.2902373671531677
# Epoch [1/5], BatchStep[1/64], Loss: 0.21267662942409515
# Epoch [1/5], BatchStep[1/64], Loss: 0.21258755028247833
# Epoch [1/5], BatchStep[1/64], Loss: 0.2119113653898239
# Epoch [1/5], BatchStep[1/64], Loss: 0.21127919852733612
# Epoch [1/5], BatchStep[1/64], Loss: 0.29022958874702454
# Epoch [1/5], BatchStep[1/64], Loss: 0.21122753620147705
# Epoch [1/5], BatchStep[1/64], Loss: 0.2090103030204773
# Epoch [1/5], BatchStep[1/64], Loss: 0.21318231523036957
# Epoch [1/5], BatchStep[1/64], Loss: 0.21128249168395996
# Epoch [1/5], BatchStep[1/64], Loss: 0.2106066346168518
# Epoch [1/5], BatchStep[1/64], Loss: 0.28982192277908325
# Epoch [1/5], BatchStep[1/64], Loss: 0.20974116027355194
# Epoch [1/5], BatchStep[1/64], Loss: 0.2902280390262604
# Epoch [1/5], BatchStep[1/64], Loss: 0.29034367203712463
# Epoch [1/5], BatchStep[1/64], Loss: 0.2121814489364624
# Epoch [1/5], BatchStep[1/64], Loss: 0.212885320186615
# Epoch [1/5], BatchStep[1/64], Loss: 0.2117452621459961
# Epoch [1/5], BatchStep[1/64], Loss: 0.2900557816028595
# Epoch [1/5], BatchStep[1/64], Loss: 0.2903672456741333
# Epoch [1/5], BatchStep[1/64], Loss: 0.2901320457458496
# Epoch [1/5], BatchStep[1/64], Loss: 0.2128690630197525
# Epoch [1/5], BatchStep[1/64], Loss: 0.21295244991779327
# Epoch [1/5], BatchStep[1/64], Loss: 0.21054905652999878
# Epoch [1/5], BatchStep[1/64], Loss: 0.29045069217681885
# Epoch [1/5], BatchStep[1/64], Loss: 0.21184752881526947
# Epoch [1/5], BatchStep[1/64], Loss: 0.21237127482891083
# Epoch [1/5], BatchStep[1/64], Loss: 0.29040512442588806
# Epoch [1/5], BatchStep[1/64], Loss: 0.2118733674287796
# Epoch [1/5], BatchStep[1/64], Loss: 0.20852869749069214
# Epoch [1/5], BatchStep[1/64], Loss: 0.2900775969028473
# Epoch [1/5], BatchStep[1/64], Loss: 0.29030054807662964
# Epoch [1/5], BatchStep[1/64], Loss: 0.21181008219718933
# Epoch [1/5], BatchStep[1/64], Loss: 0.21276569366455078
# Epoch [1/5], BatchStep[1/64], Loss: 0.2121799737215042
# Epoch [1/5], BatchStep[1/64], Loss: 0.21252211928367615
# Epoch [1/5], BatchStep[1/64], Loss: 0.21303081512451172
# Epoch [1/5], BatchStep[1/64], Loss: 0.2901308834552765
# Epoch [1/5], BatchStep[1/64], Loss: 0.21373264491558075
# Epoch [1/5], BatchStep[1/64], Loss: 0.21154183149337769
# Epoch [1/5], BatchStep[1/64], Loss: 0.2116241306066513
# Epoch [1/5], BatchStep[1/64], Loss: 0.21325622498989105
# Epoch [1/5], BatchStep[1/64], Loss: 0.2901833653450012
# Epoch [1/5], BatchStep[1/64], Loss: 0.21196435391902924
# Epoch [1/5], BatchStep[1/64], Loss: 0.21078428626060486
# Epoch [1/5], BatchStep[1/64], Loss: 0.21298903226852417
# Epoch [1/5], BatchStep[1/64], Loss: 0.2905062735080719
# Epoch [1/5], BatchStep[1/64], Loss: 0.21273672580718994
# Epoch [1/5], BatchStep[1/64], Loss: 0.2117885798215866
# Epoch [1/5], BatchStep[1/64], Loss: 0.21080948412418365
# Epoch [1/5], BatchStep[1/64], Loss: 0.2136017233133316
# Epoch [1/5], BatchStep[1/64], Loss: 0.2104632407426834
# Epoch [1/5], BatchStep[1/64], Loss: 0.2121555060148239
# Epoch [1/5], BatchStep[1/64], Loss: 0.2108386605978012
# Epoch [1/5], BatchStep[1/64], Loss: 0.210874542593956
# Epoch [1/5], BatchStep[1/64], Loss: 0.2901466190814972
# Epoch [1/5], BatchStep[1/64], Loss: 0.2134142965078354
# Epoch [1/5], BatchStep[1/64], Loss: 0.211896151304245
# Epoch [1/5], BatchStep[1/64], Loss: 0.2902785837650299
# Epoch [1/5], BatchStep[1/64], Loss: 0.21252311766147614
# Epoch [1/5], BatchStep[1/64], Loss: 0.2906571328639984
# Epoch [1/5], BatchStep[1/64], Loss: 0.21279171109199524
# Epoch [1/5], BatchStep[1/64], Loss: 0.21065491437911987
# Epoch [1/5], BatchStep[1/64], Loss: 0.21337178349494934
# Epoch [1/5], BatchStep[1/64], Loss: 0.28988128900527954
# Epoch [1/5], BatchStep[1/64], Loss: 0.2134392261505127
# Epoch [1/5], BatchStep[1/64], Loss: 0.21172834932804108
# Epoch [1/5], BatchStep[1/64], Loss: 0.29032421112060547
# Epoch [1/5], BatchStep[1/64], Loss: 0.2091621607542038
# Epoch [1/5], BatchStep[1/64], Loss: 0.21211212873458862
# Epoch [1/5], BatchStep[1/64], Loss: 0.2902528941631317
# Epoch [1/5], BatchStep[1/64], Loss: 0.29017090797424316
# Epoch [1/5], BatchStep[1/64], Loss: 0.21318289637565613
# Epoch [1/5], BatchStep[1/64], Loss: 0.21298056840896606
# Epoch [1/5], BatchStep[1/64], Loss: 0.21333062648773193
# Epoch [1/5], BatchStep[1/64], Loss: 0.21079334616661072
# Epoch [1/5], BatchStep[1/64], Loss: 0.2136862725019455
# Epoch [1/5], BatchStep[1/64], Loss: 0.2901931703090668
# Epoch [1/5], BatchStep[1/64], Loss: 0.21218225359916687
# Epoch [1/5], BatchStep[1/64], Loss: 0.2900991141796112
# Epoch [1/5], BatchStep[1/64], Loss: 0.21192100644111633
# Epoch [1/5], BatchStep[1/64], Loss: 0.21291570365428925
# Epoch [1/5], BatchStep[1/64], Loss: 0.21121613681316376
# Epoch [1/5], BatchStep[1/64], Loss: 0.21339435875415802
# Epoch [1/5], BatchStep[1/64], Loss: 0.2098967730998993
# Epoch [1/5], BatchStep[1/64], Loss: 0.21098792552947998
# Epoch [1/5], BatchStep[1/64], Loss: 0.29015129804611206
# Epoch [1/5], BatchStep[1/64], Loss: 0.2905423641204834
# Epoch [1/5], BatchStep[1/64], Loss: 0.2905976474285126
# Epoch [1/5], BatchStep[1/64], Loss: 0.20893585681915283
# Epoch [1/5], BatchStep[1/64], Loss: 0.21334290504455566
# Epoch [1/5], BatchStep[1/64], Loss: 0.2138158679008484
# Epoch [1/5], BatchStep[1/64], Loss: 0.21061402559280396
# Epoch [1/5], BatchStep[1/64], Loss: 0.29043859243392944
# Epoch [1/5], BatchStep[1/64], Loss: 0.21158649027347565
# Epoch [1/5], BatchStep[1/64], Loss: 0.2904246747493744
# Epoch [1/5], BatchStep[1/64], Loss: 0.21151499450206757
# Epoch [1/5], BatchStep[1/64], Loss: 0.21129865944385529
# Epoch [1/5], BatchStep[1/64], Loss: 0.29063278436660767
# Epoch [1/5], BatchStep[1/64], Loss: 0.21210123598575592
# Epoch [1/5], BatchStep[1/64], Loss: 0.21296770870685577
# Epoch [1/5], BatchStep[1/64], Loss: 0.2136748880147934
# Epoch [1/5], BatchStep[1/64], Loss: 0.2899467647075653
# ...
# Epoch [2/5], BatchStep[11/41], Loss: 0.4599533975124359
# Epoch [2/5], BatchStep[11/41], Loss: 0.04356352612376213
# Epoch [2/5], BatchStep[11/41], Loss: 0.037548553198575974
# Epoch [2/5], BatchStep[11/41], Loss: 0.47614285349845886
# Epoch [2/5], BatchStep[11/41], Loss: 0.5109888315200806
# Epoch [2/5], BatchStep[11/41], Loss: 0.08505240082740784
# Epoch [2/5], BatchStep[11/41], Loss: 0.0618857778608799
# Epoch [2/5], BatchStep[11/41], Loss: 0.02003353089094162
# Epoch [2/5], BatchStep[11/41], Loss: 0.4322787821292877
# Epoch [2/5], BatchStep[11/41], Loss: 0.04898642376065254
# Epoch [2/5], BatchStep[11/41], Loss: 0.10799938440322876
# Epoch [2/5], BatchStep[11/41], Loss: 0.48841986060142517
# Epoch [2/5], BatchStep[11/41], Loss: 0.47767359018325806
# Epoch [2/5], BatchStep[11/41], Loss: 0.03185686469078064
# Epoch [2/5], BatchStep[11/41], Loss: 0.47426387667655945
# Epoch [2/5], BatchStep[11/41], Loss: 0.019320791587233543
# Epoch [2/5], BatchStep[11/41], Loss: 0.4634602665901184
# Epoch [2/5], BatchStep[11/41], Loss: 0.1244242787361145
# Epoch [2/5], BatchStep[11/41], Loss: 0.4631716310977936
# Epoch [2/5], BatchStep[11/41], Loss: 0.09615424275398254
# Epoch [2/5], BatchStep[11/41], Loss: 0.4955671429634094
# Epoch [2/5], BatchStep[11/41], Loss: 0.011849976144731045
# Epoch [2/5], BatchStep[11/41], Loss: 0.04755190759897232
# Epoch [2/5], BatchStep[11/41], Loss: 0.06706800311803818
# Epoch [2/5], BatchStep[11/41], Loss: 0.48960912227630615
# Epoch [2/5], BatchStep[11/41], Loss: 0.054764799773693085
# Epoch [2/5], BatchStep[11/41], Loss: 0.06278980523347855
# Epoch [2/5], BatchStep[11/41], Loss: 0.031216712668538094
# Epoch [2/5], BatchStep[11/41], Loss: 0.04107430949807167
# Epoch [2/5], BatchStep[11/41], Loss: 0.46563011407852173
# Epoch [2/5], BatchStep[11/41], Loss: 0.03222746029496193
# Epoch [2/5], BatchStep[11/41], Loss: 0.045051995664834976
# Epoch [2/5], BatchStep[11/41], Loss: 0.050232261419296265
# Epoch [2/5], BatchStep[11/41], Loss: 0.056625571101903915
# Epoch [2/5], BatchStep[11/41], Loss: 0.07422205060720444
# Epoch [2/5], BatchStep[11/41], Loss: 0.5075910091400146
# Epoch [2/5], BatchStep[11/41], Loss: 0.1301850974559784
# Epoch [2/5], BatchStep[11/41], Loss: 0.5081048011779785
# Epoch [2/5], BatchStep[11/41], Loss: 0.1376161128282547
# Epoch [2/5], BatchStep[11/41], Loss: 0.10316791385412216
# Epoch [2/5], BatchStep[11/41], Loss: 0.05770478770136833
# Epoch [2/5], BatchStep[11/41], Loss: 0.03212989494204521
# Epoch [2/5], BatchStep[11/41], Loss: 0.45075514912605286
# Epoch [2/5], BatchStep[11/41], Loss: 0.047691646963357925
# Epoch [2/5], BatchStep[11/41], Loss: 0.04452464357018471
# Epoch [2/5], BatchStep[11/41], Loss: 0.05374052748084068
# Epoch [2/5], BatchStep[11/41], Loss: 0.04457145184278488
# Epoch [2/5], BatchStep[11/41], Loss: 0.057262297719717026
# Epoch [2/5], BatchStep[11/41], Loss: 0.45436087250709534
# Epoch [2/5], BatchStep[11/41], Loss: 0.00961814820766449
# Epoch [2/5], BatchStep[11/41], Loss: 0.06691773980855942
# Epoch [2/5], BatchStep[11/41], Loss: 0.49111002683639526
# Epoch [2/5], BatchStep[11/41], Loss: 0.025717416778206825
# Epoch [2/5], BatchStep[11/41], Loss: 0.5101278424263
# Epoch [2/5], BatchStep[11/41], Loss: 0.4791735112667084
# Epoch [2/5], BatchStep[11/41], Loss: 0.023562362417578697
